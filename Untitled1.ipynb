# %%
import face_recognition
import numpy as np
from matplotlib import pyplot as plt
import matplotlib
import dlib
import openface
import cv2

# %%
x_data = np.load('dataset_x.npy')
y_data = np.load('dataset_y.npy')

# %%
bush = x_data[23]

# %%
# bush = np.array(bush, dtype='uint8')
# bush = cv2.resize(bush, (150,150), interpolation = cv2.INTER_AREA)
# plt.imshow(bush)
# matplotlib.image.imsave('./face_recognition_test/bush.png', bush)

# %%
# bush_1 = x_data[56]
# bush_1 = np.array(bush_1, dtype='uint8')
# bush_1 = cv2.resize(bush_1, (150,150), interpolation = cv2.INTER_AREA)
# plt.imshow(bush_1)
# matplotlib.image.imsave('./face_recognition_test/bush_1.png', bush_1)

# %%
# someone = x_data[93]
# print(y_data[93])

# %%
# someone = np.array(someone, dtype='uint8')
# someone = cv2.resize(someone, (150,150), interpolation = cv2.INTER_AREA)
# plt.imshow(someone)
# matplotlib.image.imsave('./face_recognition_test/erdogan.png', someone)

# %%
# bush_image = face_recognition.load_image_file('./face_recognition_test/bush.png')
# # bush_image = np.mean(bush_image, axis = 2)
# # cv2.imwrite('./face_recognition_test/bush.png', bush_image)
# # bush_image = face_recognition.load_image_file('./face_recognition_test/bush_net.jpg')
# bush_encoding = face_recognition.face_encodings(bush_image)[0]
# plt.imshow(bush_image, cmap = 'gray')

# %%
# bush_1_image = face_recognition.load_image_file('./face_recognition_test/bush_1.png')
# # bush_1_image = np.mean(bush_1_image, axis = 2)
# # bush_1_image = cv2.resize(bush_1_image, (150,150), interpolation = cv2.INTER_AREA)
# # cv2.imwrite('./face_recognition_test/bush_net_1.jpg', bush_1_image)
# # bush_1_image = face_recognition.load_image_file('./face_recognition_test/bush_net_1.jpg')
# bush_1_encoding = face_recognition.face_encodings(bush_1_image)[0]
# plt.imshow(bush_1_image)

# %%
bush_image = face_recognition.load_image_file('./celebrities/Will_Smith/12.jpeg')
# bush_image = np.mean(bush_image, axis = 2)
# bush_image = cv2.resize(bush_image, (150,150), interpolation = cv2.INTER_AREA)
# cv2.imwrite('./face_recognition_test/bush_net.jpg', bush_image)
# bush_image = face_recognition.load_image_file('./face_recognition_test/bush_net.jpg')
bush_encoding = face_recognition.face_encodings(bush_image)[0]
plt.imshow(bush_image)

# %%
bush_1_image = face_recognition.load_image_file('./celebrities/Will_Smith/4.jpeg')
# bush_1_image = np.mean(bush_1_image, axis = 2)
# bush_1_image = cv2.resize(bush_1_image, (150,150), interpolation = cv2.INTER_AREA)
# cv2.imwrite('./face_recognition_test/bush_net_1.jpg', bush_1_image)
# bush_1_image = face_recognition.load_image_file('./face_recognition_test/bush_net_1.jpg')
bush_1_encoding = face_recognition.face_encodings(bush_1_image)[0]
plt.imshow(bush_1_image)

# %%
someone_image = face_recognition.load_image_file('./face_recognition_test/erdogan_net.jpg')
# someone_image = np.mean(someone_image, axis = 2)
# someone_image = cv2.resize(someone_image, (150,150), interpolation = cv2.INTER_AREA)
# cv2.imwrite('./face_recognition_test/erdogan_net.jpg', someone_image)
# someone_image = face_recognition.load_image_file('./face_recognition_test/erdogan_net.jpg')
someone_encoding = face_recognition.face_encodings(someone_image)[0]
plt.imshow(someone_image)

# %%
result = face_recognition.compare_faces([someone_encoding], bush_1_encoding)

# %%
if result[0]:
    print('Same person')
else:
    print('Not the same person')
# Out:
# Not the same person

# %%
print(bush_encoding)
# Out:
# [-8.72884318e-02  1.13671742e-01  2.82450654e-02  6.40167445e-02
#  -1.07953109e-01  7.82736577e-03 -5.97697943e-02 -6.83279783e-02
#   9.63932574e-02 -1.36132762e-02  2.19382733e-01  1.35568734e-02
#  -2.25072101e-01 -9.25851166e-02 -5.84417582e-02  1.89174682e-01
#  -2.06296265e-01 -8.68996605e-02 -1.56000525e-01 -8.60486478e-02
#  -1.34087875e-02  2.93937176e-02  9.97357070e-02 -3.83208203e-03
#  -1.30511791e-01 -3.31349105e-01 -3.93794887e-02 -6.11632019e-02
#   5.52326404e-02 -6.09404258e-02  3.09053808e-04  1.81426629e-02
#  -2.39410982e-01 -1.08982787e-01  1.12713100e-02 -6.96741045e-03
#  -5.05126119e-02 -1.34400902e-02  1.85647339e-01 -2.79723760e-03
#  -1.36532649e-01  8.03110823e-02  9.10866335e-02  2.70639479e-01
#   2.51134336e-01  5.19929081e-02  2.62607168e-02 -4.88100611e-02
#   4.93931994e-02 -2.75899827e-01 -9.80070606e-03  1.45668760e-01
#   1.36908531e-01  5.33661470e-02  6.77208006e-02 -8.29508752e-02
#  -3.14472616e-02  1.85329065e-01 -1.41015947e-01  7.48106092e-02
#  -3.34243700e-02 -2.44216621e-02  8.34355876e-03 -6.25689104e-02
#   1.36645526e-01  4.77604792e-02 -5.13273068e-02 -1.35865107e-01
#   1.60789311e-01 -1.30863935e-01 -5.38559258e-02  5.87802790e-02
#  -6.56553432e-02 -2.07677931e-01 -3.76801431e-01 -9.58566181e-03
#   3.50550920e-01  1.21584401e-01 -1.52908832e-01  8.31300952e-03
#  -3.94532494e-02 -6.04088120e-02 -3.94926555e-02 -9.05217323e-03
#  -8.76618251e-02 -9.37177166e-02 -9.68108624e-02  5.25884703e-02
#   2.07694486e-01 -4.48578782e-02 -1.08823413e-02  2.09338635e-01
#   3.36837694e-02 -7.50714764e-02  8.06331448e-03  9.07232165e-02
#  -9.88140777e-02  2.00694632e-02 -1.48054942e-01 -1.45729762e-02
#   2.78417729e-02 -1.07320994e-01  4.73871268e-02  6.89517409e-02
#  -1.79769769e-01  9.86439362e-02 -2.93834452e-02 -4.11096103e-02
#  -6.77000405e-03  4.05052379e-02 -1.02926202e-01  7.29111605e-04
#   1.80954427e-01 -2.27288231e-01  2.49653250e-01  2.64426351e-01
#  -3.08216214e-02  1.09515809e-01  4.53358814e-02  5.39802983e-02
#  -5.18188439e-02  2.96301059e-02 -9.35395434e-02 -1.54704079e-01
#  -1.12933898e-02 -7.28009194e-02  3.70162725e-02  7.95262456e-02]

# %%
print(bush_1_encoding)
# Out:
# [-0.14401436  0.11222851  0.04006867  0.02039471 -0.12298066  0.00074221
#  -0.02309598 -0.10188974  0.0350899  -0.0188873   0.21517199 -0.05600887
#  -0.26908138 -0.0827914  -0.03367687  0.16823973 -0.13676399 -0.08666862
#  -0.18574354 -0.10867421 -0.05143177  0.01763599  0.07071903 -0.00983606
#  -0.06621898 -0.33621028 -0.02734259 -0.09225565  0.05804811 -0.02230288
#  -0.05050231  0.01210629 -0.26194394 -0.12434584  0.04948875  0.05952801
#  -0.05827928 -0.03460545  0.21226029 -0.06060132 -0.11729786  0.05786713
#   0.13099033  0.21071967  0.20627084  0.02348501  0.02511959 -0.01879936
#   0.11599281 -0.2529099   0.00598509  0.13609697  0.15437199  0.08776064
#   0.08342639 -0.10238484 -0.00986367  0.18527533 -0.10962903  0.00698025
#  -0.00896785 -0.02897478 -0.06390475 -0.0789426   0.21138325  0.08706912
#  -0.07559699 -0.16703442  0.14658448 -0.11789114 -0.04393161  0.04514557
#  -0.0921668  -0.11652159 -0.30087879  0.06944085  0.25504342  0.07236382
#  -0.19284604  0.01084436 -0.04429153 -0.04231993 -0.00945603  0.00234439
#  -0.0375973  -0.05648924 -0.06654809 -0.00602895  0.21704498 -0.08025422
#   0.01888294  0.18302627  0.02261614 -0.0310865   0.01729489  0.05858025
#  -0.11428443 -0.04005862 -0.14936763  0.02465288  0.06208398 -0.07541342
#  -0.01572557  0.05780211 -0.19066133  0.07218479 -0.08046752 -0.02488157
#  -0.03186432 -0.07878648 -0.04886775  0.02331976  0.13571069 -0.24057363
#   0.28988421  0.20468038 -0.09085605  0.08643594  0.06511828 -0.00879875
#   0.01757951  0.06012958 -0.1347297  -0.20303333  0.08726711 -0.06925796
#  -0.03486797  0.02237654]

# %%
print(np.all(bush_encoding == bush_1_encoding))
# Out:
# False

# %%
print(np.allclose(bush_encoding, bush_1_encoding))
# Out:
# False
